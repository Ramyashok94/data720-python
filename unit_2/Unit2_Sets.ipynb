# %% [markdown]
# # Graded: x of 5 correct
# - [x] Function accepts list
# - [x] Function uses set
# - [x] Function returns list of uniques
# - [x] Tested with myList
# - [x] Tested with larger and non-numerical values
#
# Comments:

# %% [markdown]
# ## Unit 2 Sets Quiz
# * The objective of this quiz is for you to write code that uses sets.
# * Please write a `function` called `keep_unique` that should do the following:
#     * Accept an input list.
#     * Return another list that contains only the unique elements in the input list.
# * Print out the number of items in the original list and the number of unique elements in the list.
# * A list called `myList` is included below for you to test your code.
#     * Please test you code with other larger lists as well as lists with non-numerical values.

# %%
## List for testing
myList = [0, 1, 22, 1, 34, 67, 0, 67, 120, 33, 33, 0, 1]

# %%
# Write the code for your program below.
def keep_unique(myList):
    set1= set(myList)
    newList = list(set1)
    return newList

uniqueList = keep_unique(myList)
print(f'Original list has {len(myList)} elements and unique list has {len(uniqueList)} elements')

myListNonNumeric =["apple", "river", "cloud", "forest", "breeze",
    "ocean", "shadow", "apple", "meadow", "river",
    "lantern", "cloud", "ember", "forest", "breeze",
    "twilight", "ocean", "apple", "shadow", "river",
    "mountain", "willow", "feather", "stone", "river",
    "sunrise", "petal", "brook", "shadow", "breeze",
    "apple", "river", "cloud", "forest", "meadow",
    "lantern", "twilight", "ocean", "ember", "willow",
    "feather", "stone", "sunrise", "petal", "brook"]
uniqueList2 = keep_unique(myListNonNumeric)
print(f'Original list has {len(myListNonNumeric)} elements and unique list has {len(uniqueList2)} elements')

numeric_list = [
    3, 7, 12, 3, 8, 15, 7, 21, 3, 12,
    18, 7, 15, 21, 3, 8, 12, 18, 15, 21,
    4, 9, 4, 9, 16, 4, 8, 12, 16, 9,
    20, 12, 16, 8, 20, 4, 9, 16, 12, 8,
    7, 15, 21, 7, 3, 12, 18, 21, 15, 3,
    5, 10, 5, 10, 15, 5, 10, 20, 15, 10,
    25, 5, 10, 15, 20, 25, 5, 15, 10, 20,
    12, 18, 24, 12, 6, 18, 24, 12, 6, 18,
    24, 12, 6, 18, 24, 12, 6, 18, 24, 12,
    3, 6, 9, 3, 6, 9, 12, 15, 18, 3,
    6, 9, 12, 15, 18, 3, 6, 9, 12, 15,
    18, 3, 6, 9, 12, 15, 18, 3, 6, 9
]
uniqueList3 = keep_unique(numeric_list)
print(f'Original list has {len(numeric_list)} elements and unique list has {len(uniqueList3)} elements')
# Out:
# Original list has 13 elements and unique list has 7 elements
# Original list has 45 elements and unique list has 18 elements
# Original list has 120 elements and unique list has 16 elements
