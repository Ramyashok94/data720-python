# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits.axes_grid1.inset_locator import inset_axes
from matplotlib.gridspec import GridSpec

from PIL import Image

with Image.open("cells.png") as img:
    img_array = np.array(img)

# %%
x= np.linspace(1,10,100)
y1 = np.sin(x)
y2 = np.exp(x)

#create one subplot

fig, ax1 = plt.subplots()

ax1.plot(x,y1, color ="blue")
ax1.set_ylabel("Sin(X)",color = "blue")
ax1.tick_params(axis="y", labelcolor ="blue")

ax2 =  ax1.twinx()  # create another axis on the other side uses same x axis.
ax2.plot(x,y2, color ="red")
ax2.set_ylabel("Exp(X)",color = "red")
ax2.tick_params(axis="y", labelcolor ="red")

# %%
fig,ax = plt.subplots()

ax.plot(x,y1, color = "blue")
ax.set_title("Main plot sin(x)", color ="blue")

axinst = inset_axes(ax,width="30%",height="30%",loc ="lower right")
axinst.plot(x,y2, color="red")
axinst.set_title("Exp(x)", color="red")

plt.show()

# %%
y3=np.cos(x)

fig = plt.figure(figsize = (8,6))

gs = GridSpec(2,2,figure= fig)

ax1 = fig.add_subplot(gs[0,:])
ax1.plot(x,y1,color="blue")

ax2 = fig.add_subplot(gs[1,0])
ax2.plot(x,y2,color="blue")

ax3 = fig.add_subplot(gs[1,1])
ax3.plot(x,y3, color="blue")
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.imshow(img_array)
plt.show()

# %%
fig , axe = plt.subplots(1, 3,figsize=(15,19)) # 1 row, 3 columns

axe[0].imshow(img_array[...,0]) # 0 indicates all the elements from img_array and in channel red indicated by 0
axe[1].imshow(img_array[...,1])
axe[2].imshow(img_array[...,2])

plt.show()

# %%
x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)

X, Y = np.meshgrid(x, y)
Z = np.sin(np.sqrt(X**2 + Y**2))

fig = plt.figure()
axe=fig.add_subplot(111,projection="3d")
axe.plot_surface(X,Y,Z, cmap="viridis")
plt.show()
