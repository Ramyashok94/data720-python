# %% [markdown]
# # Graded: x of 8 correct
# - [x] Create figure with one subplot
# - [x] Plot one line
# - [x] Plot two lines
# - [x] Change line colors
# - [x] Label axes
# - [x] Title chart
# - [x] Switch to scatter plot
# - [x] Change marker sizes
#
# Comments:

# %% [markdown]
# # Unit 3 Short Understanding - Scatter and line plots
# Your answers in each cell will build off/modify the code you wrote in the previous cell, so copy and paste as necessary.

# %% [markdown]
# The following cell provides some data.

# %%
import random

num_points = 10
x1 = range(num_points)
y1 = [random.randint(0, 10) for _ in range(num_points)]
z1 = [random.randint(5, 20) for _ in range(num_points)]

x2 = range(num_points)
y2 = [random.randint(0, 10) for _ in range(num_points)]
z2 = [random.randint(5, 20) for _ in range(num_points)]

# %% [markdown]
# In the cell below, correctly import Matplotlib

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# Create a new figure with one subplot

# %%
plt.figure(figsize=(8,6))
plt.subplot(1,1,1)
plt.show()

# %% [markdown]
# Plot the `x1` and `y1` variables as a line plot with their data on their corresponding axes.

# %%
plt.figure(figsize=(8,6))
plt.subplot(1,1,1)
plt.plot(x1,y1)
plt.show()

# %% [markdown]
# Add the plot of `x2` and `y2` to the same plot.

# %%
plt.figure(figsize=(8,6))
plt.subplot(1,1,1)
plt.plot(x1,y1)
plt.plot(x2,y2)
plt.show()

# %% [markdown]
# Change the colors of the lines to `lightblue` (`x1/y1`) and `darkblue` (`x2/y2`).

# %%
plt.figure(figsize=(8,6))
plt.subplot(1,1,1)
plt.plot(x1,y1, color ="lightblue")
plt.plot(x2,y2, color = "darkblue")
plt.show()

# %% [markdown]
# Label the x-axis `X` and y-axis `Y`

# %%
plt.figure(figsize=(8,6))
plt.subplot(1,1,1)
plt.plot(x1,y1, color ="lightblue")
plt.plot(x2,y2, color = "darkblue")
plt.xlabel("X")
plt.ylabel("Y")
plt.show()

# %% [markdown]
# Title the plot `Random data`

# %%
plt.figure(figsize=(8,6))
plt.subplot(1,1,1)
plt.plot(x1,y1, color ="lightblue")
plt.plot(x2,y2, color = "darkblue")
plt.xlabel("X")
plt.ylabel("Y")
plt.title("Random data")
plt.show()

# %% [markdown]
# Now switch the plot to a scatter plot.

# %%
plt.figure(figsize=(8,6))
plt.subplot(1,1,1)
plt.scatter(x1,y1, color ="lightblue")
plt.scatter(x2,y2, color = "darkblue")
plt.xlabel("X")
plt.ylabel("Y")
plt.title("Random data")
plt.show()

# %% [markdown]
# Finally, make the marker sizes for `x1/y1` correspond to `z1` and `x2/y2` correspond to `z2`

# %%
plt.figure(figsize=(8,6))
plt.subplot(1,1,1)
plt.scatter(x1,y1, color ="lightblue", s=z1)
plt.scatter(x2,y2, color = "darkblue", s=z2)
plt.xlabel("X")
plt.ylabel("Y")
plt.title("Random data")
plt.show()
