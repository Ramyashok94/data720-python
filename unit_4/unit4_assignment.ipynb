# %% [markdown]
# # Graded: 14 of 14 correct
# 1. Song class
# - [x] Title
# - [x] Length
# - [x] Magic function for string
#
# 2. Album class
# - [x] Title
# - [x] Song list
# - [x] Artist
# - [x] Year
# - [x] Print function
# - [x] Magic functions for comparing years
#
# 3. Artist class
# - [x] Name
# - [x] Discography
# - [x] Sort albums function
# - [x] Print function
#
# 4. Adding data
# - [x] Function(s) add data
#
# Comments:

# %% [markdown]
# # Assignment 4: Creating a music library
# In this example, you will create classes for song, album, and artist objects. Here are some things to consider:
# 1. Think of each larger class to be a container of objects from the smaller class (e.g. an Album contains a list of Songs)
# 2. Because these classes do not share many characteristics, you don't need to subclass to accomplish the task

# %% [markdown]
# ## Create a new class for songs
# Start by creating a class called `Song` with the following attributes:
# 1. title: a string representing the song title
# 2. length: a string representing the length of the song
# 4. A magic function that allows you to print a string representation of the song as shown below
#         <br />Title: title
#         <br />Length: length s (the s stands for seconds)

# %%
class Song:
    def __init__(self,title,length):
        self.title = title
        self.length = length
    def __str__(self):
        string = f'''
Title :{self.title}
Length : {self.length} s
                '''
        return string

    def __repr__(self):
        return self.__str__()

# %% [markdown]
# ## Create an album class
# An album is a collection of songs. Make a class called `Album` that has the following characteristics:
# 1. title: a string representing the album title
# 2. songs: a list of Song objects within the album
# 3. artist: a string representing the artist name
# 4. year: an integer representation of the album release year
# 5. A function that allows you to print a string representation of the album as shown below
#         <br />Title: album title
#         <br />Artist: artist
#         <br />Year: year
#         <br />Songs: print each song on the album
# 6. Magic function(s) for mathematical comparisons based on year for sorting purposes. This can be accomplished using the `sorted()` function (see documentation). **Note:** Do not use the `key` argument of `sorted`, as this would defeat the purpose of including magic functions. Instead define enough mathematical functions to satisfy the default usage `sorted([list of class objects])`

# %%
class Album:
    def __init__(self, title, songs, artist,year):
        self.title = title
        self.songs = songs
        self.artist = artist
        self.year= year
    def __str__(self):
        title_str = ''
        for song in self.songs:
            #print(type(song))
            title_str += song.title+"\n"
        string = f'''
Title: {self.title}
Artist: {self.artist}
Year: {self.year}
Songs: {title_str}
                '''
        return string
    def __lt__(self,other):
        if isinstance(other,Album):
            print(self.year < other.year)

    def __repr__(self):
        return self.__str__()

# %% [markdown]
# ## Create an artist class
# An artist is a collection of songs. Make a class called `Artist` that has the following characteristics:
# 1. name: a string representing the artist name
# 2. discography: a list of Album objects made by this artist
# 3. A function that sorts the artist's albums by year
# 4. A function that allows you to print a string representation of the artist as shown below
#         <br />Artist: artist
#         <br />Albums: print each album (sorted by year)

# %%
class Artist:
    def __init__(self,name,discography):
        self.name = name
        self.discography = discography
    def __lt__(self,other):
      return self.discography.year<other.discography.year
    def __str__(self):     
       string = f'''
Artist: {self.name}
Albums: {self.discography}
                '''
       return string

# %% [markdown]
# ## Add a batch of data into the new structures
# The file `music_data.json` contains a batch of music data. JSON files are structured similarly to dictionaries and are used for many purposes (like configuration files, for example). The cell below uses the built-in `json` Python library to read the file in as a dictionary. The keys are artist names ("Taylor Swift", "Drake", "BTS") and each key will return a list of dictionaries, each an album, that have `title`, `year`, and `songs` keys, the latter returning another list of dictionaries containing the `title` and `length` (in seconds) of each song. Here is a summary of how the data are formatted:
# ```
# {artist name: [
#         {
#             title: album title,
#             year: year,
#             songs: [
#                 {
#                     title: song title,
#                     length: length
#                 },
#                 ...
#             ]
#         },
#         ...
#     ]
# }
#
# ```

# %%
import json
with open('music_data.json', 'r') as f:
    artist_dict = json.load(f)

# %% [markdown]
# Create one or more functions that add these data to each of the data structures you have created.

# %%
def datamapping(jsonData):
    artist = []
        
    for artist_name, album_list in jsonData.items():
        discography=[]

        for album_values in album_list:
            songs = []

            for song_list in album_values["songs"]:

                song = Song(title = song_list["title"], length = song_list["length"])

                songs.append(song)

            albumobj = Album(title=album_values["title"], year = album_values["year"], songs = songs,artist = artist_name)

            #print(album)

            discography.append(albumobj)

         

        artistobj = Artist(name= artist_name, discography=discography)

        artist.append(artistobj)
            
    return artist

def get_artist_album(artist_list,artist_name):
    for artist in artist_list:
        if artist.name.lower() == artist_name.lower():
            return artist.discography

        else:
            return None

# %% [markdown]
# Finally, print any artist's discography and the track list for one of their albums

# %%
artist = datamapping(artist_dict)
albums= get_artist_album(artist, "Taylor Swift")

if albums:
    for album in albums:
        print(f"Album = {album.title} , Year = {album.year}")

        for song in album.songs:

            print(f"Song: {song.title} , Length ={song.length}")
        print('\n')
else:
    print("Album not found")
# Out:
# Album = 1989 , Year = 2014
# Song: Welcome to New York , Length =212
# Song: Blank Space , Length =231
# Song: Style , Length =231
# Song: Out of the Woods , Length =235
# Song: All You Had to Do Was Stay , Length =193
# Song: Shake It Off , Length =219
# Song: I Wish You Would , Length =207
# Song: Bad Blood , Length =211
# Song: Wildest Dreams , Length =220
# Song: How You Get the Girl , Length =247
# Song: This Love , Length =250
# Song: I Know Places , Length =195
# Song: Clean , Length =270
#
#
# Album = Fearless , Year = 2008
# Song: Fearless , Length =241
# Song: Fifteen , Length =294
# Song: Love Story , Length =235
# Song: Hey Stephen , Length =254
# Song: White Horse , Length =234
# Song: You Belong with Me , Length =231
# Song: Breathe , Length =263
# Song: Tell Me Why , Length =200
# Song: You're Not Sorry , Length =261
# Song: The Way I Loved You , Length =243
# Song: Forever & Always , Length =225
# Song: The Best Day , Length =245
# Song: Change , Length =280
#
#
# Album = Lover , Year = 2019
# Song: I Forgot That You Existed , Length =171
# Song: Cruel Summer , Length =178
# Song: Lover , Length =221
# Song: The Man , Length =190
# Song: The Archer , Length =211
# Song: I Think He Knows , Length =173
# Song: Miss Americana & the Heartbreak Prince , Length =234
# Song: Paper Rings , Length =222
# Song: Cornelia Street , Length =287
# Song: Death by a Thousand Cuts , Length =199
# Song: London Boy , Length =190
# Song: Soon You'll Get Better , Length =202
# Song: False God , Length =200
# Song: You Need to Calm Down , Length =171
# Song: Afterglow , Length =223
# Song: Me! , Length =193
# Song: It's Nice to Have a Friend , Length =150
# Song: Daylight , Length =293
#
#
# Album = Midnights , Year = 2022
# Song: Lavender Haze , Length =202
# Song: Maroon , Length =218
# Song: Anti-Hero , Length =200
# Song: Snow on the Beach , Length =256
# Song: You're on Your Own, Kid , Length =194
# Song: Midnight Rain , Length =174
# Song: Question...? , Length =210
# Song: Vigilante Shit , Length =164
# Song: Bejeweled , Length =194
# Song: Labyrinth , Length =247
# Song: Karma , Length =204
# Song: Sweet Nothing , Length =188
# Song: Mastermind , Length =191
#
#
# Album = Red , Year = 2012
# Song: State of Grace , Length =295
# Song: Red , Length =223
# Song: Treacherous , Length =242
# Song: I Knew You Were Trouble , Length =219
# Song: All Too Well , Length =329
# Song: 22 , Length =232
# Song: I Almost Do , Length =244
# Song: We Are Never Ever Getting Back Together , Length =193
# Song: Stay Stay Stay , Length =205
# Song: The Last Time , Length =299
# Song: Holy Ground , Length =202
# Song: Sad Beautiful Tragic , Length =284
# Song: The Lucky One , Length =240
# Song: Everything Has Changed , Length =245
# Song: Starlight , Length =220
# Song: Begin Again , Length =237
#
#
# Album = Reputation , Year = 2017
# Song: …Ready for It? , Length =208
# Song: End Game , Length =244
# Song: I Did Something Bad , Length =238
# Song: Don't Blame Me , Length =236
# Song: Delicate , Length =232
# Song: Look What You Made Me Do , Length =211
# Song: So It Goes… , Length =227
# Song: Gorgeous , Length =209
# Song: Getaway Car , Length =233
# Song: King of My Heart , Length =214
# Song: Dancing with Our Hands Tied , Length =211
# Song: Dress , Length =230
# Song: This Is Why We Can't Have Nice Things , Length =207
# Song: Call It What You Want , Length =203
# Song: New Year's Day , Length =235
#
#
# Album = Speak Now , Year = 2010
# Song: Mine , Length =230
# Song: Sparks Fly , Length =260
# Song: Back to December , Length =293
# Song: Speak Now , Length =240
# Song: Dear John , Length =403
# Song: Mean , Length =237
# Song: The Story of Us , Length =265
# Song: Never Grow Up , Length =290
# Song: Enchanted , Length =353
# Song: Better than Revenge , Length =217
# Song: Innocent , Length =302
# Song: Haunted , Length =242
# Song: Last Kiss , Length =367
# Song: Long Live , Length =317
#
#
# Album = Taylor Swift , Year = 2006
# Song: Tim McGraw , Length =234
# Song: Picture to Burn , Length =175
# Song: Teardrops on My Guitar , Length =215
# Song: A Place in This World , Length =202
# Song: Cold as You , Length =241
# Song: The Outside , Length =209
# Song: Tied Together with a Smile , Length =251
# Song: Stay Beautiful , Length =238
# Song: Should've Said No , Length =244
# Song: Mary's Song (Oh My My My) , Length =215
# Song: Our Song , Length =204
#
#
# Album = evermore , Year = 2020
# Song: Willow , Length =214
# Song: Champagne Problems , Length =244
# Song: Gold Rush , Length =185
# Song: 'Tis the Damn Season , Length =229
# Song: Tolerate It , Length =245
# Song: No Body, No Crime , Length =215
# Song: Happiness , Length =315
# Song: Dorothea , Length =225
# Song: Coney Island , Length =275
# Song: Ivy , Length =260
# Song: Cowboy like Me , Length =275
# Song: Long Story Short , Length =215
# Song: Marjorie , Length =257
# Song: Closure , Length =180
# Song: Evermore , Length =304
#
#
# Album = folklore , Year = 2020
# Song: The 1 , Length =210
# Song: Cardigan , Length =239
# Song: The Last Great American Dynasty , Length =231
# Song: Exile , Length =285
# Song: My Tears Ricochet , Length =255
# Song: Mirrorball , Length =209
# Song: Seven , Length =208
# Song: August , Length =261
# Song: This Is Me Trying , Length =195
# Song: Illicit Affairs , Length =190
# Song: Invisible String , Length =252
# Song: Mad Woman , Length =237
# Song: Epiphany , Length =289
# Song: Betty , Length =294
# Song: Peace , Length =234
# Song: Hoax , Length =220
