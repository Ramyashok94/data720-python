# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
cars = pd.read_csv("MY2023_Fuel_Consumption_Ratings.csv")

cars.head()
# Out:
#    Model Year   Make              Model  Vehicle Class  Engine Size (L)  \
# 0        2023  Acura            Integra      Full-size              1.5
# 1        2023  Acura     Integra A-SPEC      Full-size              1.5
# 2        2023  Acura     Integra A-SPEC      Full-size              1.5
# 3        2023  Acura         MDX SH-AWD     SUV: Small              3.5
# 4        2023  Acura  MDX SH-AWD Type S  SUV: Standard              3.0
#
#    Cylinders Transmission Fuel Type  Fuel Consumption City (L/100 km)  \
# 0          4          AV7         Z                               7.9
# 1          4          AV7         Z                               8.1
# 2          4           M6         Z                               8.9
# 3          6         AS10         Z                              12.6
# 4          6         AS10         Z                              13.8
#
#    Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 0                              6.3                               7.2
# 1                              6.5                               7.4
# 2                              6.5                               7.8
# 3                              9.4                              11.2
# 4                             11.2                              12.4
#
#    Fuel Consumption Comb (mpg)  CO2 Emissions (g/km)  CO2 Rating  Smog Rating
# 0                           39                   167           6            7
# 1                           38                   172           6            7
# 2                           36                   181           6            6
# 3                           25                   263           4            5
# 4                           23                   291           4            5

# %%
#listing columns
cars.columns.to_list()
# Out:
# ['Model Year',
#  'Make',
#  'Model',
#  'Vehicle Class',
#  'Engine Size (L)',
#  'Cylinders',
#  'Transmission',
#  'Fuel Type',
#  'Fuel Consumption City (L/100 km)',
#  'Fuel Consumption Hwy (L/100 km)',
#  'Fuel Consumption Comb (L/100 km)',
#  'Fuel Consumption Comb (mpg)',
#  'CO2 Emissions (g/km)',
#  'CO2 Rating',
#  'Smog Rating']

# %%
#removing unwanted columns

cars= cars.drop(columns=[
    'Model Year',
    'Transmission',
    'Fuel Consumption City (L/100 km)',
    'Fuel Consumption Hwy (L/100 km)',
    'Fuel Consumption Comb (L/100 km)'
])

# %%
print(cars['Vehicle Class'].unique())
# Out:
# ['Full-size' 'SUV: Small' 'SUV: Standard' 'Compact' 'Mid-size'
#  'Minicompact' 'Two-seater' 'Subcompact' 'Station wagon: Small'
#  'Station wagon: Mid-size' 'Pickup truck: Small' 'Pickup truck: Standard'
#  'Minivan' 'Special purpose vehicle']

# %%
#ploting the vehicle class

sns.histplot(data=cars, x="Vehicle Class")
plt.xticks(rotation=70,ha="right",rotation_mode="anchor")
plt.show()

# %%
#binwidth for histogram
sns.histplot(data=cars, x="Vehicle Class",binwidth=1)
plt.xticks(rotation=70,ha="right")
plt.show()

# %%
#binwidth for fuel consumption

sns.histplot(data=cars, x='Fuel Consumption Comb (mpg)')
plt.show()

# %%
sns.histplot(data=cars, x='Fuel Consumption Comb (mpg)',binwidth=1)
plt.show()

# %%
#with density
sns.histplot(data=cars, x='Fuel Consumption Comb (mpg)',binwidth=1,kde=True)
plt.show()

# %%
#histogram is hard to see, so we can use kde

sns.kdeplot(data=cars, x='Fuel Consumption Comb (mpg)',hue="Vehicle Class")
plt.show()

# %%
#we can get the subset of vehicle class = suv

subset = cars[cars["Vehicle Class"].str.contains("SUV")]
sns.kdeplot(data=subset, x='Fuel Consumption Comb (mpg)',hue="Vehicle Class")
plt.show()

# %%
#violin plot shows distribution across categorical variable

plt.figure(figsize = (10,6))
sns.violinplot(data=cars, x="Cylinders",y="Fuel Consumption Comb (mpg)")
# Out:
# <Axes: xlabel='Cylinders', ylabel='Fuel Consumption Comb (mpg)'>

# %%
plt.figure(figsize=(10,7))
sns.scatterplot(data=cars, x="Engine Size (L)",y="Fuel Consumption Comb (mpg)")
plt.show()

# %%
plt.figure(figsize=(10,7))
sns.scatterplot(data=cars, x="Engine Size (L)",y="Fuel Consumption Comb (mpg)",hue="Vehicle Class")
plt.show()
